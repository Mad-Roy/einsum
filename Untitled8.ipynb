# %% [markdown]
# <a href="https://colab.research.google.com/github/Mad-Roy/einsum/blob/master/Untitled8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from google.colab import drive

#drive.mount('/content/drive')

checkpoints = '/content/drive/MyDrive/colab_files/SWMS20'
if not os.path.exists(checkpoints):
    os.makedirs(checkpoints)

# %cd /content/drive/MyDrive/colab_files/SWMS20

! git clone https://github.com/felisat/federated-learning.git

# %%
import os
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# navigate to the cloned repository
# %cd /content/drive/MyDrive/colab_files/SWMS20/federated-learning
# Out:
# /content/drive/MyDrive/colab_files/SWMS20/federated-learning

# %%
# !python federated_learning.py
# Out:
# Torch Version:  2.3.0+cu121
# Running 1 Experiments..
#
# Hyperparameters:
#  - dataset                 mnist
#  - net                     logistic
#  - iterations              2000
#  - n_clients               2000
#  - participation_rate      0.5
#  - classes_per_client      10
#  - batch_size              1
#  - balancedness            1.0
#  - momentum                0.9
#  - log_frequency           30
#  - log_path                results/trash/
#  - finished                False
#  - log_id                  33470
#  - communication_rounds    2000
#  - compression_up          ['none', {}]
#  - accumulation_up         False
#  - compression_down        ['none', {}]
#  - accumulation_down       False
#  - lr                      0.04
#  - aggregation             mean
#  - local_iterations        1
#
# ...
# Failed to download (trying next):
# HTTP Error 403: Forbidden
#
# ...
# 100% 9912422/9912422 [00:02<00:00, 4467493.19it/s]
# ...
